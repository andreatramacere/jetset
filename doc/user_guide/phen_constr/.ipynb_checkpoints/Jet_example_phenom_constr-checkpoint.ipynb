# %%
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pylab as plt
from jetset.test_data_helper import  test_SEDs
from jetset.data_loader import ObsData,Data
from jetset.plot_sedfit import PlotSED
from jetset.test_data_helper import  test_SEDs

# %%
print(test_SEDs[1])
data=Data(data_table=test_SEDs[1])
# Out:
# /Users/orion/anaconda3/lib/python3.7/site-packages/jetset-1.0.2-py3.7-macosx-10.7-x86_64.egg/jetset/test_data/SEDs_data/SED_MW_Mrk421.dat

# %%
# %matplotlib notebook
sed_data=ObsData(data_table=data)
sed_data.group_data(bin_width=0.2)
sed_data.add_systematics(0.2,[10.**6,10.**29])
# Out:
# ...
#
# ***  binning data  ***
# ---> N bins= 89
# ---> bin_widht= 0.2
# ...

# %%
sed_data.plot_sed()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
from jetset.sed_shaper import  SEDShape
my_shape=SEDShape(sed_data)
my_shape.eval_indices()
p=my_shape.plot_indices()
p.rescale(y_min=-15,y_max=-6)
# Out:
# ...
#
# *** evaluating spectral indices for data ***
# ---> initial range for index radio  set to [6.000000,10.000000]
# ---> range for index radio updated  to [6.000000,10.000000]
# ---> name = radio            range=[6.000 ,10.000] log(Hz)  photon.val=-1.402754e+00, err=1.250721e-01
#
# ---> initial range for index radio_mm  set to [10.000000,11.000000]
# ---> range for index radio_mm updated  to [10.000000,11.000000]
# ---> name = radio_mm         range=[10.000,11.000] log(Hz)  photon.val=-1.290348e+00, err=3.549105e-02
#
# ---> initial range for index mm_IR  set to [11.000000,13.000000]
# ---> range for index mm_IR updated  to [10.300000,13.700000]
# ---> name = mm_IR            range=[10.300,13.700] log(Hz)  photon.val=-1.109667e+00, err=5.233777e-02
#
# ---> initial range for index IR_Opt  set to [13.000000,14.000000]
# ---> range for index IR_Opt updated  to [12.500000,14.500000]
# ...

# %%
mm,best_fit=my_shape.sync_fit(check_host_gal_template=True,
                  Ep_start=None,
                  minimizer='lsb',
                  silent=True,
                  fit_range=[10,21])


#mm.minimizer.minos_errors()
#p=my_shape.plot_sahpe_fit()
#x,y,z,fig,ax=mm.minimizer.draw_contour('Ep','b')
#x,y,fig,ax=mm.minimizer.draw_profile('Ep')
# Out:
# ...
#
# *** Log-Polynomial fitting of the synchrotron component ***
# ---> first blind fit run,  fit range: [10, 21]
# -------------------------------------------------------------------------------------------------------------------
# model parameters:
#  Name             | Type                 | Units            | value         | phys. boundaries              | log
# -------------------------------------------------------------------------------------------------------------------
#  b                | curvature            |                  | -1.000000e+00 | [-1.000000e+01,+0.000000e+00] | False
#  c                | third-degree         |                  | -1.000000e+00 | [-1.000000e+01,+1.000000e+01] | False
#  Ep               | peak freq            | Hz               | +1.400000e+01 | [+0.000000e+00,+3.000000e+01] | True
#  Sp               | peak flux            | erg cm^-2 s^-1   | -1.000000e+01 | [-3.000000e+01,+0.000000e+00] | True
# ...

# %%
best_fit.show_report()
# Out:
# **************************************************************************************************
# Fit report
#
# Model: sync-shape-fit
# -------------------------------------------------------------------------------------------------------------------
# model parameters:
#  Name             | Type                 | Units            | value         | phys. boundaries              | log
# -------------------------------------------------------------------------------------------------------------------
#  b                | curvature            |                  | -1.654332e-01 | [-1.000000e+01,+0.000000e+00] | False
#  c                | third-degree         |                  | -1.199314e-02 | [-1.000000e+01,+1.000000e+01] | False
#  Ep               | peak freq            | Hz               | +1.673010e+01 | [+0.000000e+00,+3.000000e+01] | True
#  Sp               | peak flux            | erg cm^-2 s^-1   | -9.485651e+00 | [-3.000000e+01,+0.000000e+00] | True
# ...

# %%
x, y, fig,a=mm.minimizer.draw_mnprofile('Sp')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d717ed4f5ccc> in <module>
# ----> 1 x, y, fig,a=mm.minimizer.draw_mnprofile('Sp')
#
# NameError: name 'mm' is not defined

# %%
my_shape.IC_fit(fit_range=[21,29],minimizer='minuit')
p=my_shape.plot_sahpe_fit()
# Out:
# ...
#
# *** Log-Polynomial fitting of the IC component ***
# ---> fit range: [21, 29]
# ---> LogCubic fit
# <hr>
# <table>
#     <tr>
#         <td title="Minimum value of function">FCN = 3.4399462169488366</td>
#         <td title="Total number of call to FCN so far">TOTAL NCALL = 214</td>
#         <td title="Number of call in last migrad">NCALLS = 214</td>
#     </tr>
#     <tr>
#         <td title="Estimated distance to minimum">EDM = 3.309614688792438e-05</td>
#         <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#         <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#         UP = 1.0</td>
#     </tr>
# </table>
# <table>
#     <tr>
#         <td align="center" title="Validity of the migrad call">Valid</td>
#         <td align="center" title="Validity of parameters">Valid Param</td>
#         <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
# ...

# %%
from jetset.obs_constrain import ObsConstrain
from jetset.model_manager import  FitModel
from jetset.minimizer import fit_SED
sed_obspar=ObsConstrain(beaming=25,
                        B_range=[0.01,0.1],
                        distr_e='plc',
                        t_var_sec=3*86400,
                        nu_cut_IR=1E12,
                        SEDShape=my_shape)


jet=sed_obspar.constrain_SSC_model(electron_distribution_log_values=True)
jet.parameters.gamma_cut.val=5.55
jet.eval()
pl=jet.plot_model(sed_data=sed_data)
pl.rescale(y_min=-15,x_min=7,x_max=29)
# Out:
# ...
#
# ***  constrains parameters from observable ***
# -------------------------------------------------------------------------------------------------------------------
# model parameters:
#  Name             | Type                 | Units            | value         | phys. boundaries              | log
# -------------------------------------------------------------------------------------------------------------------
#  B                | magnetic_field       | G                | +1.000000e-01 | [+0.000000e+00,No           ] | False
#  N                | electron_density     | cm^-3            | +1.000000e+02 | [+0.000000e+00,No           ] | False
#  R                | region_size          | cm               | +1.569897e+01 | [+0.000000e+00,+3.000000e+01] | True
#  beam_obj         | beaming              |                  | +1.000000e+01 | [+1.000000e+00,No           ] | False
# ...

# %%
from jetset.model_manager import  FitModel
from jetset.plot_sedfit import PlotSED
jet.set_gamma_grid_size(200)
#pl=PlotSED(sed_data=sed_data)
fit_model=FitModel( jet=jet, name='SSC-best-fit',template=None)
fit_model.eval()
pl=fit_model.plot_model(sed_data=sed_data)
pl.rescale(y_min=-15,x_min=7,x_max=29)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
from jetset.model_manager import  FitModel

jet.set_gamma_grid_size(200)

fit_model=FitModel( jet=jet, name='SSC-best-fit',template=my_shape.host_gal)

fit_model.freeze('z_cosm')
#fit_model.set_par('gamma0_log_parab',5.5)
fit_model.freeze('gmax')
fit_model.freeze('R')
fit_model.freeze('nuFnu_p_host')
fit_model.freeze('nu_scale')
fit_model.show_pars()

model_minimizer,best_fit=fit_SED(fit_model,sed_data,10.0**12,10**29.0,fitname='SSC-best-fit-lppl',minimizer='minuit')
p2=fit_model.plot_model(sed_data=sed_data)
p2.rescale(y_min=-15,x_min=7,x_max=29)
# Out:
# -------------------------------------------------------------------------------------------------------------------
# model parameters:
#  Name             | Type                 | Units            | value         | phys. boundaries              | log
# -------------------------------------------------------------------------------------------------------------------
#  B                | magnetic_field       | G                | +1.232369e-02 | [+0.000000e+00,No           ] | False
#  N                | electron_density     | cm^-3            | +8.993612e-02 | [+0.000000e+00,No           ] | False
#  R                | region_size          | cm               | +1.701584e+01 | [+0.000000e+00,+3.000000e+01] | True
#  beam_obj         | beaming              |                  | +2.500000e+01 | [+1.000000e+00,No           ] | False
#  gamma_cut        | turn-over-energy     | Lorentz-factor   | +5.635646e+00 | [+0.000000e+00,+8.000000e+00] | True
# ...

# %%
model_minimizer.minimizer.minos_errors()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-7773f2be8684> in <module>()
# ----> 1 model_minimizer.minimizer.minos_errors()
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/jetset-1.2.0-py3.6-macosx-10.7-x86_64.egg/jetset/minimizer.py in minos_errors(self, par)
#     723             par=self.minuit_par_name_dict[par]
#     724         self.calls = 0
# --> 725         self.minuit_fun.minos(var=par)
#     726         self.minuit_fun.print_param()
#     727         self.asymm_errors = [(self.minuit_fun.merrors[(k,1.0)],self.minuit_fun.merrors[(k,-1.0)]) for k in self.minuit_fun.errors.keys()]
#
# iminuit/_libiminuit.pyx in iminuit._libiminuit.Minuit.minos()
#
# RuntimeError: Function mimimum is not valid. Make sure migrad converge first

# %%
x,y,f,ax=model_minimizer.minimizer.draw_profile(par='N',bound=2)
# Out:
# / minim function calls=100, chisq=18.475678 UL part=-0.000000
# <img src="data:image/png;base64,..." width="640">

# %%
x,y,z,fig,ax=model_minimizer.minimizer.draw_contour('beam_obj','B',bound=20.5,levels=np.arange(4))
# Out:
# - minim function calls=9030, chisq=309.603295 UL part=-0.000000

# %%
from jetset.mcmc import McmcSampler
jet.set_gamma_grid_size(100)
mcmc=McmcSampler(model_minimizer)
mcmc.run_sampler(nwalkers=150,burnin=10,threads=1,steps=50)
# Out:
# - progress=102.000% calls=7650 accepted=5912

# %%
f=mcmc.corner_plot()
# Out:
# <img src="data:image/png;base64,..." width="1390">

# %%
f=mcmc.sampler_out.plot_par('N')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f=mcmc.sampler_out.plot_par('beam_obj')

# %%
mcmc.seve_run('test_run')

# %%
from jetset.mcmc import SamplerOutput
s=SamplerOutput.from_file('test_run')

# %%
f=s.plot_par('beam_obj',log_plot=False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# compare to minuit mnprofile

# %%
model_minimizer.minimizer.draw_mnprofile(par='beam_obj',bound=2)
# Out:
# / minim function calls=9860, chisq=61.474005 UL part=-0.000000
# <img src="data:image/png;base64,..." width="640">
# (array([22.07455394, 22.20748236, 22.34041078, 22.47333919, 22.60626761,
#         22.73919603, 22.87212445, 23.00505287, 23.13798128, 23.2709097 ,
#         23.40383812, 23.53676654, 23.66969496, 23.80262338, 23.93555179,
#         24.06848021, 24.20140863, 24.33433705, 24.46726547, 24.60019389,
#         24.7331223 , 24.86605072, 24.99897914, 25.13190756, 25.26483598,
#         25.39776439, 25.53069281, 25.66362123, 25.79654965, 25.92947807]),
#  array([5.19814831, 2.92880896, 0.96548503, 3.94097599, 3.02972893,
#         3.04076743, 2.70269742, 1.78598985, 0.        , 1.99913744,
#         1.82251238, 1.62534295, 1.62043604, 1.39008317, 1.57385423,
#         1.60901378, 1.68544258, 1.76038733, 1.80019961, 2.09226728,
#         2.17721212, 2.83523164, 2.69257434, 2.74136245, 3.29028366,
#         3.78632604, 4.26666299, 4.54227187, 5.15834409, 5.05410802]),
# ...
